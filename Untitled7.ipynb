# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshipatil-24/Sakshi-vaibhav-patil-/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Create lists
list1 = [1, 2, 3]
list2 = [4, 5, 6]

# Concatenation
result = list1 + list2
print("Concatenation:", result)

# Repetition
print("Repetition:", list1 * 2)

# Length
print("Length of list1:", len(list1))

# Maximum and Minimum
print("Maximum:", max(list2))
print("Minimum:", min(list2))
# Out:
# Concatenation: [1, 2, 3, 4, 5, 6]
# Repetition: [1, 2, 3, 1, 2, 3]
# Length of list1: 3
# Maximum: 6
# Minimum: 4

# %%
# Create a list
numbers = [10, 20, 30, 40, 50]

# Check membership
print("List:", numbers)

# Using 'in'
print(20 in numbers)   # True
print(60 in numbers)   # False

# Using 'not in'
print(60 not in numbers)  # True
print(10 not in numbers)  # False
# Out:
# List: [10, 20, 30, 40, 50]
# True
# False
# True
# False

# %%
# Create a list
fruits = ["apple", "banana", "cherry", "mango", "grapes"]

print(fruits)

# Indexing
print("First element:", fruits[0])
print("Third element:", fruits[2])

# Negative indexing
print("Last element:", fruits[-1])
print("Second last:", fruits[-2])

# Slicing
print("Elements from index 1 to 3:", fruits[1:4])
print("First three elements:", fruits[:3])
print("Last two elements:", fruits[-2:])
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'grapes']
# First element: apple
# Third element: cherry
# Last element: grapes
# Second last: mango
# Elements from index 1 to 3: ['banana', 'cherry', 'mango']
# First three elements: ['apple', 'banana', 'cherry']
# Last two elements: ['mango', 'grapes']

# %%
# Create a list
numbers = [1, 2, 3, 4, 5]

print("Original list:", numbers)

# Update
numbers[2] = 10
print("After update:", numbers)

# Append
numbers.append(6)
print("After append:", numbers)

# Insert
numbers.insert(1, 20)
print("After insert:", numbers)

# Delete (remove by value)
numbers.remove(4)
print("After remove:", numbers)

# Delete (pop by index)
numbers.pop(2)
print("After pop:", numbers)

# Delete entire list element
del numbers[0]
print("After del:", numbers)
# Out:
# Original list: [1, 2, 3, 4, 5]
# After update: [1, 2, 10, 4, 5]
# After append: [1, 2, 10, 4, 5, 6]
# After insert: [1, 20, 2, 10, 4, 5, 6]
# After remove: [1, 20, 2, 10, 5, 6]
# After pop: [1, 20, 10, 5, 6]
# After del: [20, 10, 5, 6]
